# %% [markdown]
# # СЛОЖЕНИЕ И ПРОИЗВЕДЕНИЕ ВЕРОЯТНОСТЕЙ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Задачи

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
P1 = 0,5 # 1ый стрелок
P2 = 0,8 # 2ой стрелок
P = 0.5 * 0.2 + 0.5 * 0.8
P #итого вер-ть попадания 1ой пробоины
# Out:
# 0.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
P1 = 0.8 # 1ый аналитик
P2 = 0.7 # 2ой аналитик
P3 = 0.6 # 3ий аналитик
Q1 = 0.2
Q2 = 0.3
Q3 = 0.4
P = 1 - (Q1*Q2*Q3)
P
# Out:
# 0.976

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
P1 = 4/14 #черный шар из урны
P2 = 9/14 #черный шар из 2ой урны

P = 4/14 * 9/14
P
# Out:
# 0.18367346938775508

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br> Пусть P - вероятность попадания в цель при 1 выстрел </br>
# <br> Тогда вер-ть хотя бы 1 попадния в цель при 4х выстрелах равна 1 - (1-P)^4, т.е. Q </br>

# %% [markdown]
# 1-(1-P)^4 = 0.9984 => P = 0.8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A и F, т.к. если вытянем туз, то вероятность вытянуть туз в событии F изменится (тузов станет в колоде меньше)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
P = 3/10 * 2/9 * 1/8
P
# т.к. билеты извлекаются
# Out:
# 0.008333333333333333

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br> У каждого робота возможны два направления, их всего три => число возможных комбинаций направлений 2 * 2 * 2 = 8 </br>
# <br> Из всех комбинаций лишь две удовлетвояют условию, что они не встретятся (движение по часовой или против часовой стрелки</br>
# <br> Значит P = 2/8 = 0.25 </br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A и C - остальные зависимы

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Таких комбинаций 19 => P = 19/36 = 0.528
